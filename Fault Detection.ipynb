# %%
import pandas as pd
import numpy as np
from glob import glob
import os
import glob
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


start_date = '2023-11-30'    
end_date   = '2024-10-30'    

temp_variation_threshold = 5.0  # °C threshold for weather-related fault adjustment

# Columns for plotting Forecast vs Actual and MSE
forecast_columns = ['Forecast', 'Actual Values']
mse_columns = ['MSE']

# ======================
# Preload and Process Temperature Data 
# ======================
temp_df = pd.read_csv('/Users/mohamadhamza/Desktop/Finaleeee/Temp Halmstad 20-25.csv', sep=';')
print("Temperature data columns:", temp_df.columns)

# Clean the temperature values and convert to numeric
temp_df['Temp oC'] = temp_df['Temp oC'].str.replace(',', '.')
temp_df['Temp oC'] = pd.to_numeric(temp_df['Temp oC'], errors='coerce')

# Convert Date to datetime and set as index
temp_df['Date'] = pd.to_datetime(temp_df['Date'], errors='coerce')
temp_df.set_index('Date', inplace=True)

# Resample to obtain daily average temperatures
temp_daily = temp_df['Temp oC'].resample('D').mean()



cumulative_TP = 0
cumulative_FN = 0
cumulative_FP = 0
# ======================
# Process Every Dataset in dataset_dict
# ======================
for dataset_name, df in dataset_dict.items():
    print("\n==============================")
    print("Processing dataset:")
    print("==============================\n")
    
    # Filter the dataset for the unified date range
    df_filtered = df.loc[start_date:end_date]
    
    # ----------------------------
    # 1. Plot Forecast vs. Actual Values
    # ----------------------------
    missing_forecast_cols = [col for col in forecast_columns if col not in df_filtered.columns]
    if missing_forecast_cols:
        print("Dataset '' missing forecast columns: {missing_forecast_cols}")
    else:
        plt.figure(figsize=(12, 6))
        for column in forecast_columns:
            plt.plot(df_filtered.index, df_filtered[column], label=column)
        plt.title("")
        plt.xlabel("Date")
        plt.ylabel("Values")
        plt.legend()
        plt.grid(True)
        plt.show()


    # ----------------------------
    # 3. SPC Fault Detection with Weather Adjustment
    # ----------------------------
    # Use the same filtered dataset for SPC analysis
    df_spc = df_filtered.copy()
    
    # Merge with temperature data (based on the same date range)
    df_spc = df_spc.merge(temp_daily, how='left', left_index=True, right_index=True)
    
    # Check for necessary columns before error calculation
    if not all(col in df_spc.columns for col in forecast_columns):
        print(f"Dataset '{dataset_name}' does not include both 'Forecast' and 'Actual Values' for SPC analysis.")
        continue
    
    # Calculate error as difference between Actual Values and Forecast
    df_spc['Error'] = df_spc['Actual Values'] - df_spc['Forecast']
    
    # Compute SPC statistics: center line, UCL, and LCL
    process_mean = df_spc['Error'].mean()
    process_std = df_spc['Error'].std()
    UCL = process_mean + 0.5 * process_std
    LCL = process_mean - 0.5 * process_std
    print(f"Dataset '': Process Mean = {process_mean:.3f}, UCL = {UCL:.3f}, LCL = {LCL:.3f}")
    
    # Flag fault points based on the SPC limits
    df_spc['FaultFlag'] = (df_spc['Error'] > UCL) | (df_spc['Error'] < LCL)
    # Create groups of consecutive fault points
    df_spc['GroupID'] = (df_spc['FaultFlag'] != df_spc['FaultFlag'].shift()).cumsum()

    final_fault_indices = []

    # For each individual fault day (no grouping)
    for idx, row in df_spc[df_spc['FaultFlag']].iterrows():
        print(f"Evaluating fault at {idx.date()}")

        # 1) Start with today’s temp
        temps = []
        if not np.isnan(row['Temp oC']):
            temps.append(row['Temp oC'])

        # 2) Yesterday
        prev_day = idx - pd.Timedelta(days=1)
        if prev_day in df_spc.index:
            prev_temp = df_spc.at[prev_day, 'Temp oC']
            if not np.isnan(prev_temp):
                temps.append(prev_temp)
                print(f"  + Included previous day ({prev_day.date()}): {prev_temp:.2f}°C")

        # 3) Tomorrow
        next_day = idx + pd.Timedelta(days=1)
        if next_day in df_spc.index:
            next_temp = df_spc.at[next_day, 'Temp oC']
            if not np.isnan(next_temp):
                temps.append(next_temp)
                print(f"  + Included next day     ({next_day.date()}): {next_temp:.2f}°C")

        # 4) Compute variation
        if temps:
            variation = max(temps) - min(temps)
        else:
            variation = 0.0

        # 5) Decide and record
        if variation < temp_variation_threshold:
            final_fault_indices.append(idx)
            print(f"  -> Fault Detected: Temp Variation = {variation:.2f}°C")
        else:
            print(f"  -> Fault Rejected: Temp Variation = {variation:.2f}°C")

    # Mark final faults
    df_spc['FinalFault'] = False
    df_spc.loc[final_fault_indices, 'FinalFault'] = True

    # Plot the SPC chart with weather-adjusted fault detection
    plt.figure(figsize=(14, 7))
    plt.plot(df_spc.index, df_spc['Error'], marker='o', linestyle='-', label='Error')
    plt.axhline(UCL, color='red', linestyle='--', label=f'UCL = {UCL:.3f}')
    plt.axhline(LCL, color='red', linestyle='--', label=f'LCL = {LCL:.3f}')
    plt.scatter(df_spc[df_spc['FinalFault']].index, df_spc[df_spc['FinalFault']]['Error'],
                color='red', label='Detected Faults', zorder=5)
    plt.title(": SPC Fault Detection with Weather Adjustment\nfrom {start_date} to {end_date}")
    plt.xlabel("Date")
    plt.ylabel("Error")
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()


    # 1) Extract the common ID (everything before "_cleaned")
    base_id = dataset_name.split('_cleaned')[0]
    
    # 2) Build the mask filename from that ID
    mask_filename = f"{base_id}_cleaned(Injected)second_mask.csv"
    mask_path     = os.path.join(mask_dir, mask_filename)

    # 3) Load & clean the mask
    mask_df = (
        pd.read_csv(mask_path, sep=',')      # mask files are comma-delimited
          .rename(columns={'time':'Date','mask':'MaskFlag'})
    )
    mask_df['Date']     = pd.to_datetime(mask_df['Date'], errors='coerce').dt.date
    mask_df['MaskFlag'] = mask_df['MaskFlag'].astype(bool)

    # 4) Build your “detected” table
    det_df = (
        df_spc.reset_index()[['Date','FinalFault']]
          .rename(columns={'FinalFault':'Detected'})
    )
    det_df['Date'] = det_df['Date'].dt.date

    # 5) Merge & compute precision
    comparison_df = (
        pd.merge(det_df, mask_df, on='Date', how='outer')
          .fillna(False)   # missing → False
          .sort_values('Date')
    )
    TP = ((comparison_df['Detected']) & (comparison_df['MaskFlag'])).sum()
    FP = ((comparison_df['Detected']) & (~comparison_df['MaskFlag'])).sum()
    precision = TP / (TP + FP) if (TP + FP) else float('nan')

    print(f"TP={TP}, FP={FP}, precision={precision:.3f}")
    TP = ((comparison_df['Detected'] == True) &
      (comparison_df['MaskFlag'] == True)).sum()

    FP = ((comparison_df['Detected'] == True) &
      (comparison_df['MaskFlag'] == False)).sum()

    precision = TP / (TP + FP) if (TP + FP) > 0 else float('nan')

    print(f"True Positives  (TP): {TP}")
    print(f"False Positives (FP): {FP}")
    print(f"Precision         : {precision:.3f}")
    # True Positives  = injected *and* detected
    # assume comparison_df has boolean columns Detected and MaskFlag:
    TP = ((comparison_df['Detected']) & (comparison_df['MaskFlag'])).sum()
    FP = ((comparison_df['Detected']) & (~comparison_df['MaskFlag'])).sum()
    FN = ((~comparison_df['Detected']) & (comparison_df['MaskFlag'])).sum()
    
    # Increment cumulative TP, FN, and FP
    cumulative_TP += TP
    cumulative_FN += FN
    cumulative_FP += FP
    

    precision = TP / (TP + FP) 
    recall    = TP / (TP + FN)

    print(f"TP={TP}, FP={FP}, FN={FN}")
    print(f"Precision = {precision:.3f}")
    print(f"Recall = {recall:.3f}")
    


# At the end, after all datasets are processed:
overall_recall = cumulative_TP / (cumulative_TP + cumulative_FN) 
overall_precision = cumulative_TP / (cumulative_TP + cumulative_FP) 

print("\n====================================")
print(f"Overall Recall across all buildings   : {overall_recall:.3f}")
print(f"Overall Precision across all buildings: {overall_precision:.3f}")
print("====================================")
# Out:
# Temperature data columns: Index(['Date', 'Temp oC', 'Unnamed: 2', 'Unnamed: 3'], dtype='object')
#
# ==============================
# Processing dataset:
# ==============================
# Dataset '': Process Mean = -0.013, UCL = 0.084, LCL = -0.110
# Evaluating fault at 2023-11-30
#   + Included next day     (2023-12-01): -3.23°C
#   -> Fault Detected: Temp Variation = 0.68°C
# Evaluating fault at 2023-12-03
#   + Included previous day (2023-12-02): -6.91°C
#   + Included next day     (2023-12-04): -4.49°C
#   -> Fault Detected: Temp Variation = 4.27°C
# Evaluating fault at 2023-12-04
#   + Included previous day (2023-12-03): -8.76°C
#   + Included next day     (2023-12-05): -0.92°C
#   -> Fault Rejected: Temp Variation = 7.84°C
# Evaluating fault at 2023-12-05
#   + Included previous day (2023-12-04): -4.49°C
#   + Included next day     (2023-12-06): 0.46°C
#   -> Fault Detected: Temp Variation = 4.95°C
# Evaluating fault at 2023-12-06
#   + Included previous day (2023-12-05): -0.92°C
#   + Included next day     (2023-12-07): 0.15°C
#   -> Fault Detected: Temp Variation = 1.38°C
# Evaluating fault at 2023-12-07
#   + Included previous day (2023-12-06): 0.46°C
#   + Included next day     (2023-12-08): 1.10°C
#   -> Fault Detected: Temp Variation = 0.95°C
# Evaluating fault at 2023-12-13
#   + Included previous day (2023-12-12): -0.06°C
#   + Included next day     (2023-12-14): -1.07°C
#   -> Fault Detected: Temp Variation = 1.62°C
# Evaluating fault at 2023-12-14
#   + Included previous day (2023-12-13): -1.68°C
#   + Included next day     (2023-12-15): 2.58°C
#   -> Fault Detected: Temp Variation = 4.27°C
# Evaluating fault at 2023-12-15
#   + Included previous day (2023-12-14): -1.07°C
#   + Included next day     (2023-12-16): 5.32°C
#   -> Fault Rejected: Temp Variation = 6.39°C
# Evaluating fault at 2023-12-16
#   + Included previous day (2023-12-15): 2.58°C
#   + Included next day     (2023-12-17): 5.95°C
#   -> Fault Detected: Temp Variation = 3.36°C
# Evaluating fault at 2023-12-17
#   + Included previous day (2023-12-16): 5.32°C
#   + Included next day     (2023-12-18): 5.99°C
#   -> Fault Detected: Temp Variation = 0.67°C
# Evaluating fault at 2023-12-22
#   + Included previous day (2023-12-21): 3.78°C
#   + Included next day     (2023-12-23): -2.78°C
#   -> Fault Rejected: Temp Variation = 6.55°C
# Evaluating fault at 2023-12-23
#   + Included previous day (2023-12-22): 0.36°C
#   + Included next day     (2023-12-24): 0.80°C
#   -> Fault Detected: Temp Variation = 3.57°C
# Evaluating fault at 2023-12-25
#   + Included previous day (2023-12-24): 0.80°C
#   + Included next day     (2023-12-26): 3.06°C
#   -> Fault Detected: Temp Variation = 4.68°C
# Evaluating fault at 2023-12-28
#   + Included previous day (2023-12-27): 1.06°C
#   + Included next day     (2023-12-29): 5.84°C
#   -> Fault Detected: Temp Variation = 4.78°C
# Evaluating fault at 2024-01-02
#   + Included previous day (2024-01-01): 2.73°C
#   + Included next day     (2024-01-03): -2.61°C
#   -> Fault Rejected: Temp Variation = 5.33°C
# Evaluating fault at 2024-01-03
#   + Included previous day (2024-01-02): -0.76°C
#   + Included next day     (2024-01-04): -5.69°C
#   -> Fault Detected: Temp Variation = 4.92°C
# Evaluating fault at 2024-01-04
#   + Included previous day (2024-01-03): -2.61°C
#   + Included next day     (2024-01-05): -11.29°C
#   -> Fault Rejected: Temp Variation = 8.69°C
# Evaluating fault at 2024-01-08
#   + Included previous day (2024-01-07): -8.91°C
#   + Included next day     (2024-01-09): -1.76°C
#   -> Fault Rejected: Temp Variation = 7.15°C
# Evaluating fault at 2024-01-10
#   + Included previous day (2024-01-09): -1.76°C
#   + Included next day     (2024-01-11): -2.35°C
#   -> Fault Detected: Temp Variation = 0.59°C
# Evaluating fault at 2024-01-11
#   + Included previous day (2024-01-10): -1.92°C
#   + Included next day     (2024-01-12): -3.16°C
#   -> Fault Detected: Temp Variation = 1.25°C
# Evaluating fault at 2024-01-15
#   + Included previous day (2024-01-14): 1.34°C
#   + Included next day     (2024-01-16): -9.96°C
#   -> Fault Rejected: Temp Variation = 11.31°C
# Evaluating fault at 2024-01-16
#   + Included previous day (2024-01-15): -4.74°C
#   + Included next day     (2024-01-17): 0.17°C
#   -> Fault Rejected: Temp Variation = 10.13°C
# Evaluating fault at 2024-01-17
#   + Included previous day (2024-01-16): -9.96°C
#   + Included next day     (2024-01-18): -1.07°C
#   -> Fault Rejected: Temp Variation = 10.13°C
# Evaluating fault at 2024-02-03
#   + Included previous day (2024-02-02): 4.69°C
#   + Included next day     (2024-02-04): 5.54°C
#   -> Fault Detected: Temp Variation = 1.60°C
# Evaluating fault at 2024-02-06
#   + Included previous day (2024-02-05): 4.34°C
#   + Included next day     (2024-02-07): -0.89°C
#   -> Fault Rejected: Temp Variation = 5.23°C
# Evaluating fault at 2024-02-15
#   + Included previous day (2024-02-14): 4.52°C
#   + Included next day     (2024-02-16): 8.17°C
#   -> Fault Detected: Temp Variation = 3.65°C
# Evaluating fault at 2024-02-16
#   + Included previous day (2024-02-15): 5.22°C
#   + Included next day     (2024-02-17): 4.01°C
#   -> Fault Detected: Temp Variation = 4.17°C
# Evaluating fault at 2024-02-18
#   + Included previous day (2024-02-17): 4.01°C
#   + Included next day     (2024-02-19): 3.92°C
#   -> Fault Detected: Temp Variation = 1.49°C
# Evaluating fault at 2024-02-19
#   + Included previous day (2024-02-18): 2.52°C
#   + Included next day     (2024-02-20): 4.84°C
#   -> Fault Detected: Temp Variation = 2.32°C
# Evaluating fault at 2024-02-22
#   + Included previous day (2024-02-21): 5.44°C
#   + Included next day     (2024-02-23): 6.66°C
#   -> Fault Detected: Temp Variation = 1.23°C
# Evaluating fault at 2024-02-26
#   + Included previous day (2024-02-25): 5.59°C
#   + Included next day     (2024-02-27): 2.26°C
#   -> Fault Detected: Temp Variation = 3.33°C
# Evaluating fault at 2024-02-27
#   + Included previous day (2024-02-26): 4.41°C
#   + Included next day     (2024-02-28): 4.07°C
#   -> Fault Detected: Temp Variation = 2.15°C
# Evaluating fault at 2024-03-01
#   + Included previous day (2024-02-29): 5.76°C
#   + Included next day     (2024-03-02): 8.10°C
#   -> Fault Detected: Temp Variation = 2.34°C
# Evaluating fault at 2024-03-03
#   + Included previous day (2024-03-02): 8.10°C
#   + Included next day     (2024-03-04): 5.38°C
#   -> Fault Detected: Temp Variation = 2.72°C
# Evaluating fault at 2024-03-04
#   + Included previous day (2024-03-03): 7.69°C
#   + Included next day     (2024-03-05): 3.71°C
#   -> Fault Detected: Temp Variation = 3.97°C
# Evaluating fault at 2024-03-07
#   + Included previous day (2024-03-06): 4.09°C
#   + Included next day     (2024-03-08): 2.50°C
#   -> Fault Detected: Temp Variation = 3.29°C
# Evaluating fault at 2024-03-14
#   + Included previous day (2024-03-13): 5.45°C
#   + Included next day     (2024-03-15): 9.33°C
#   -> Fault Detected: Temp Variation = 3.88°C
# Evaluating fault at 2024-03-15
#   + Included previous day (2024-03-14): 7.73°C
#   + Included next day     (2024-03-16): 5.75°C
#   -> Fault Detected: Temp Variation = 3.58°C
# Evaluating fault at 2024-03-17
#   + Included previous day (2024-03-16): 5.75°C
#   + Included next day     (2024-03-18): 0.31°C
#   -> Fault Rejected: Temp Variation = 5.44°C
# Evaluating fault at 2024-03-23
#   + Included previous day (2024-03-22): 6.04°C
#   + Included next day     (2024-03-24): 5.28°C
#   -> Fault Detected: Temp Variation = 0.76°C
# Evaluating fault at 2024-03-27
#   + Included previous day (2024-03-26): 4.94°C
#   + Included next day     (2024-03-28): 7.97°C
#   -> Fault Detected: Temp Variation = 4.55°C
# Evaluating fault at 2024-03-28
#   + Included previous day (2024-03-27): 9.49°C
#   + Included next day     (2024-03-29): 7.50°C
#   -> Fault Detected: Temp Variation = 1.99°C
# Evaluating fault at 2024-03-29
#   + Included previous day (2024-03-28): 7.97°C
#   + Included next day     (2024-03-30): 7.35°C
#   -> Fault Detected: Temp Variation = 0.62°C
# Evaluating fault at 2024-03-30
#   + Included previous day (2024-03-29): 7.50°C
#   + Included next day     (2024-03-31): 8.63°C
#   -> Fault Detected: Temp Variation = 1.28°C
# Evaluating fault at 2024-04-02
#   + Included previous day (2024-04-01): 10.17°C
#   + Included next day     (2024-04-03): -0.01°C
#   -> Fault Rejected: Temp Variation = 10.17°C
# Evaluating fault at 2024-04-03
#   + Included previous day (2024-04-02): 2.88°C
#   + Included next day     (2024-04-04): 1.85°C
#   -> Fault Detected: Temp Variation = 2.89°C
# Evaluating fault at 2024-04-06
#   + Included previous day (2024-04-05): 6.98°C
#   + Included next day     (2024-04-07): 11.95°C
#   -> Fault Detected: Temp Variation = 4.97°C
# Evaluating fault at 2024-04-07
#   + Included previous day (2024-04-06): 9.74°C
#   + Included next day     (2024-04-08): 12.18°C
#   -> Fault Detected: Temp Variation = 2.44°C
# Evaluating fault at 2024-04-09
#   + Included previous day (2024-04-08): 12.18°C
#   + Included next day     (2024-04-10): 8.63°C
#   -> Fault Detected: Temp Variation = 4.07°C
# Evaluating fault at 2024-04-11
#   + Included previous day (2024-04-10): 8.63°C
#   + Included next day     (2024-04-12): 8.74°C
#   -> Fault Detected: Temp Variation = 0.23°C
# Evaluating fault at 2024-04-12
#   + Included previous day (2024-04-11): 8.86°C
#   + Included next day     (2024-04-13): 9.74°C
#   -> Fault Detected: Temp Variation = 1.00°C
# Evaluating fault at 2024-04-13
#   + Included previous day (2024-04-12): 8.74°C
#   + Included next day     (2024-04-14): 8.60°C
#   -> Fault Detected: Temp Variation = 1.15°C
# Evaluating fault at 2024-04-15
#   + Included previous day (2024-04-14): 8.60°C
#   + Included next day     (2024-04-16): 6.30°C
#   -> Fault Detected: Temp Variation = 2.30°C
# Evaluating fault at 2024-04-19
#   + Included previous day (2024-04-18): 5.79°C
#   + Included next day     (2024-04-20): 3.13°C
#   -> Fault Detected: Temp Variation = 2.65°C
# Evaluating fault at 2024-04-20
#   + Included previous day (2024-04-19): 3.73°C
#   + Included next day     (2024-04-21): 4.27°C
#   -> Fault Detected: Temp Variation = 1.14°C
# Evaluating fault at 2024-04-21
#   + Included previous day (2024-04-20): 3.13°C
#   + Included next day     (2024-04-22): 0.87°C
#   -> Fault Detected: Temp Variation = 3.40°C
# Evaluating fault at 2024-04-22
#   + Included previous day (2024-04-21): 4.27°C
#   + Included next day     (2024-04-23): 2.71°C
#   -> Fault Detected: Temp Variation = 3.40°C
# Evaluating fault at 2024-04-23
#   + Included previous day (2024-04-22): 0.87°C
#   + Included next day     (2024-04-24): 4.89°C
#   -> Fault Detected: Temp Variation = 4.01°C
# Evaluating fault at 2024-04-24
#   + Included previous day (2024-04-23): 2.71°C
#   + Included next day     (2024-04-25): 5.62°C
#   -> Fault Detected: Temp Variation = 2.90°C
# Evaluating fault at 2024-04-25
#   + Included previous day (2024-04-24): 4.89°C
#   + Included next day     (2024-04-26): 5.89°C
#   -> Fault Detected: Temp Variation = 1.01°C
# Evaluating fault at 2024-04-26
#   + Included previous day (2024-04-25): 5.62°C
#   + Included next day     (2024-04-27): 8.26°C
#   -> Fault Detected: Temp Variation = 2.64°C
# Evaluating fault at 2024-04-28
#   + Included previous day (2024-04-27): 8.26°C
#   + Included next day     (2024-04-29): 11.44°C
#   -> Fault Rejected: Temp Variation = 7.03°C
# Evaluating fault at 2024-04-29
#   + Included previous day (2024-04-28): 15.29°C
#   + Included next day     (2024-04-30): 15.00°C
#   -> Fault Detected: Temp Variation = 3.85°C
# Evaluating fault at 2024-04-30
#   + Included previous day (2024-04-29): 11.44°C
#   + Included next day     (2024-05-01): 18.45°C
#   -> Fault Rejected: Temp Variation = 7.01°C
# Evaluating fault at 2024-05-01
#   + Included previous day (2024-04-30): 15.00°C
#   + Included next day     (2024-05-02): 18.23°C
#   -> Fault Detected: Temp Variation = 3.45°C
# Evaluating fault at 2024-05-02
#   + Included previous day (2024-05-01): 18.45°C
#   + Included next day     (2024-05-03): 17.80°C
#   -> Fault Detected: Temp Variation = 0.64°C
# Evaluating fault at 2024-05-04
#   + Included previous day (2024-05-03): 17.80°C
#   + Included next day     (2024-05-05): 13.38°C
#   -> Fault Detected: Temp Variation = 4.83°C
# Evaluating fault at 2024-05-05
#   + Included previous day (2024-05-04): 12.98°C
#   + Included next day     (2024-05-06): 10.75°C
#   -> Fault Detected: Temp Variation = 2.64°C
# Evaluating fault at 2024-05-06
#   + Included previous day (2024-05-05): 13.38°C
#   + Included next day     (2024-05-07): 10.16°C
#   -> Fault Detected: Temp Variation = 3.23°C
# Evaluating fault at 2024-05-07
#   + Included previous day (2024-05-06): 10.75°C
#   + Included next day     (2024-05-08): 11.34°C
#   -> Fault Detected: Temp Variation = 1.18°C
# Evaluating fault at 2024-05-08
#   + Included previous day (2024-05-07): 10.16°C
#   + Included next day     (2024-05-09): 11.52°C
#   -> Fault Detected: Temp Variation = 1.36°C
# Evaluating fault at 2024-05-10
#   + Included previous day (2024-05-09): 11.52°C
#   + Included next day     (2024-05-11): 12.56°C
#   -> Fault Detected: Temp Variation = 1.10°C
# Evaluating fault at 2024-05-12
#   + Included previous day (2024-05-11): 12.56°C
#   + Included next day     (2024-05-13): 14.65°C
#   -> Fault Detected: Temp Variation = 2.23°C
# Evaluating fault at 2024-05-14
#   + Included previous day (2024-05-13): 14.65°C
#   + Included next day     (2024-05-15): 17.76°C
#   -> Fault Detected: Temp Variation = 3.11°C
# Evaluating fault at 2024-05-17
#   + Included previous day (2024-05-16): 17.14°C
#   + Included next day     (2024-05-18): 18.05°C
#   -> Fault Detected: Temp Variation = 0.91°C
# Evaluating fault at 2024-05-19
#   + Included previous day (2024-05-18): 18.05°C
#   + Included next day     (2024-05-20): 17.76°C
#   -> Fault Detected: Temp Variation = 0.29°C
# Evaluating fault at 2024-05-23
#   + Included previous day (2024-05-22): 20.01°C
#   + Included next day     (2024-05-24): 16.10°C
#   -> Fault Detected: Temp Variation = 3.99°C
# Evaluating fault at 2024-05-24
#   + Included previous day (2024-05-23): 20.09°C
#   + Included next day     (2024-05-25): 19.01°C
#   -> Fault Detected: Temp Variation = 3.99°C
# Evaluating fault at 2024-05-25
#   + Included previous day (2024-05-24): 16.10°C
#   + Included next day     (2024-05-26): 19.39°C
#   -> Fault Detected: Temp Variation = 3.29°C
# Evaluating fault at 2024-05-27
#   + Included previous day (2024-05-26): 19.39°C
#   + Included next day     (2024-05-28): 15.92°C
#   -> Fault Detected: Temp Variation = 3.46°C
# Evaluating fault at 2024-06-01
#   + Included previous day (2024-05-31): 17.84°C
#   + Included next day     (2024-06-02): 19.21°C
#   -> Fault Detected: Temp Variation = 1.70°C
# Evaluating fault at 2024-06-03
#   + Included previous day (2024-06-02): 19.21°C
#   + Included next day     (2024-06-04): 16.31°C
#   -> Fault Detected: Temp Variation = 3.16°C
# Evaluating fault at 2024-06-15
#   + Included previous day (2024-06-14): 13.91°C
#   + Included next day     (2024-06-16): 16.04°C
#   -> Fault Detected: Temp Variation = 2.13°C
# Evaluating fault at 2024-06-16
#   + Included previous day (2024-06-15): 14.32°C
#   + Included next day     (2024-06-17): 15.85°C
#   -> Fault Detected: Temp Variation = 1.71°C
# Evaluating fault at 2024-06-17
#   + Included previous day (2024-06-16): 16.04°C
#   + Included next day     (2024-06-18): 14.73°C
#   -> Fault Detected: Temp Variation = 1.30°C
# Evaluating fault at 2024-06-18
#   + Included previous day (2024-06-17): 15.85°C
#   + Included next day     (2024-06-19): 14.54°C
#   -> Fault Detected: Temp Variation = 1.31°C
# Evaluating fault at 2024-06-19
#   + Included previous day (2024-06-18): 14.73°C
#   + Included next day     (2024-06-20): 15.13°C
#   -> Fault Detected: Temp Variation = 0.59°C
# Evaluating fault at 2024-06-20
#   + Included previous day (2024-06-19): 14.54°C
#   + Included next day     (2024-06-21): 16.32°C
#   -> Fault Detected: Temp Variation = 1.78°C
# Evaluating fault at 2024-06-21
#   + Included previous day (2024-06-20): 15.13°C
#   + Included next day     (2024-06-22): 14.16°C
#   -> Fault Detected: Temp Variation = 2.17°C
# Evaluating fault at 2024-06-22
#   + Included previous day (2024-06-21): 16.32°C
#   + Included next day     (2024-06-23): 15.36°C
#   -> Fault Detected: Temp Variation = 2.17°C
# Evaluating fault at 2024-08-03
#   + Included previous day (2024-08-02): 15.84°C
#   + Included next day     (2024-08-04): 17.16°C
#   -> Fault Detected: Temp Variation = 1.32°C
# Evaluating fault at 2024-09-14
#   + Included previous day (2024-09-13): 11.91°C
#   + Included next day     (2024-09-15): 12.12°C
#   -> Fault Detected: Temp Variation = 0.33°C
# Evaluating fault at 2024-09-28
#   + Included previous day (2024-09-27): 13.20°C
#   + Included next day     (2024-09-29): 11.29°C
#   -> Fault Detected: Temp Variation = 2.45°C
# Evaluating fault at 2024-09-30
#   + Included previous day (2024-09-29): 11.29°C
#   + Included next day     (2024-10-01): 10.28°C
#   -> Fault Detected: Temp Variation = 1.01°C
# Evaluating fault at 2024-10-21
#   + Included previous day (2024-10-20): 14.28°C
#   + Included next day     (2024-10-22): 12.55°C
#   -> Fault Detected: Temp Variation = 1.73°C
# Evaluating fault at 2024-10-23
#   + Included previous day (2024-10-22): 12.55°C
#   + Included next day     (2024-10-24): 10.38°C
#   -> Fault Detected: Temp Variation = 2.18°C
# Evaluating fault at 2024-10-24
#   + Included previous day (2024-10-23): 12.10°C
#   + Included next day     (2024-10-25): 10.02°C
#   -> Fault Detected: Temp Variation = 2.08°C
# Evaluating fault at 2024-10-25
#   + Included previous day (2024-10-24): 10.38°C
#   + Included next day     (2024-10-26): 11.40°C
#   -> Fault Detected: Temp Variation = 1.39°C
# Evaluating fault at 2024-10-26
#   + Included previous day (2024-10-25): 10.02°C
#   + Included next day     (2024-10-27): 11.32°C
#   -> Fault Detected: Temp Variation = 1.39°C
# Evaluating fault at 2024-10-27
#   + Included previous day (2024-10-26): 11.40°C
#   + Included next day     (2024-10-28): 11.31°C
#   -> Fault Detected: Temp Variation = 0.09°C
# Evaluating fault at 2024-10-28
#   + Included previous day (2024-10-27): 11.32°C
#   + Included next day     (2024-10-29): 11.71°C
#   -> Fault Detected: Temp Variation = 0.40°C
# Evaluating fault at 2024-10-29
#   + Included previous day (2024-10-28): 11.31°C
#   + Included next day     (2024-10-30): 11.77°C
#   -> Fault Detected: Temp Variation = 0.45°C
# Evaluating fault at 2024-10-30
#   + Included previous day (2024-10-29): 11.71°C
#   -> Fault Detected: Temp Variation = 0.05°C
# TP=16, FP=74, precision=0.178
# True Positives  (TP): 16
# False Positives (FP): 74
# Precision         : 0.178
# TP=16, FP=74, FN=14
# Precision = 0.178
# Recall = 0.533
#
# ==============================
# Processing dataset:
# ==============================
# Dataset '': Process Mean = -0.000, UCL = 0.009, LCL = -0.010
# Evaluating fault at 2023-11-30
#   + Included next day     (2023-12-01): -3.23°C
#   -> Fault Detected: Temp Variation = 0.68°C
# Evaluating fault at 2023-12-02
#   + Included previous day (2023-12-01): -3.23°C
#   + Included next day     (2023-12-03): -8.76°C
#   -> Fault Rejected: Temp Variation = 5.53°C
# Evaluating fault at 2023-12-04
#   + Included previous day (2023-12-03): -8.76°C
#   + Included next day     (2023-12-05): -0.92°C
#   -> Fault Rejected: Temp Variation = 7.84°C
# Evaluating fault at 2023-12-05
#   + Included previous day (2023-12-04): -4.49°C
#   + Included next day     (2023-12-06): 0.46°C
#   -> Fault Detected: Temp Variation = 4.95°C
# Evaluating fault at 2023-12-06
#   + Included previous day (2023-12-05): -0.92°C
#   + Included next day     (2023-12-07): 0.15°C
#   -> Fault Detected: Temp Variation = 1.38°C
# Evaluating fault at 2023-12-07
#   + Included previous day (2023-12-06): 0.46°C
#   + Included next day     (2023-12-08): 1.10°C
#   -> Fault Detected: Temp Variation = 0.95°C
# Evaluating fault at 2023-12-09
#   + Included previous day (2023-12-08): 1.10°C
#   + Included next day     (2023-12-10): 2.56°C
#   -> Fault Detected: Temp Variation = 1.46°C
# Evaluating fault at 2023-12-13
#   + Included previous day (2023-12-12): -0.06°C
#   + Included next day     (2023-12-14): -1.07°C
#   -> Fault Detected: Temp Variation = 1.62°C
# Evaluating fault at 2023-12-14
#   + Included previous day (2023-12-13): -1.68°C
#   + Included next day     (2023-12-15): 2.58°C
#   -> Fault Detected: Temp Variation = 4.27°C
# Evaluating fault at 2023-12-16
#   + Included previous day (2023-12-15): 2.58°C
#   + Included next day     (2023-12-17): 5.95°C
#   -> Fault Detected: Temp Variation = 3.36°C
# Evaluating fault at 2023-12-17
#   + Included previous day (2023-12-16): 5.32°C
#   + Included next day     (2023-12-18): 5.99°C
#   -> Fault Detected: Temp Variation = 0.67°C
# Evaluating fault at 2023-12-18
#   + Included previous day (2023-12-17): 5.95°C
#   + Included next day     (2023-12-19): 5.28°C
#   -> Fault Detected: Temp Variation = 0.71°C
# Evaluating fault at 2023-12-23
#   + Included previous day (2023-12-22): 0.36°C
#   + Included next day     (2023-12-24): 0.80°C
#   -> Fault Detected: Temp Variation = 3.57°C
# Evaluating fault at 2023-12-25
#   + Included previous day (2023-12-24): 0.80°C
#   + Included next day     (2023-12-26): 3.06°C
#   -> Fault Detected: Temp Variation = 4.68°C
# Evaluating fault at 2024-01-02
#   + Included previous day (2024-01-01): 2.73°C
#   + Included next day     (2024-01-03): -2.61°C
#   -> Fault Rejected: Temp Variation = 5.33°C
# Evaluating fault at 2024-01-03
#   + Included previous day (2024-01-02): -0.76°C
#   + Included next day     (2024-01-04): -5.69°C
#   -> Fault Detected: Temp Variation = 4.92°C
# Evaluating fault at 2024-01-04
#   + Included previous day (2024-01-03): -2.61°C
#   + Included next day     (2024-01-05): -11.29°C
#   -> Fault Rejected: Temp Variation = 8.69°C
# Evaluating fault at 2024-01-05
#   + Included previous day (2024-01-04): -5.69°C
#   + Included next day     (2024-01-06): -11.58°C
#   -> Fault Rejected: Temp Variation = 5.89°C
# Evaluating fault at 2024-01-08
#   + Included previous day (2024-01-07): -8.91°C
#   + Included next day     (2024-01-09): -1.76°C
#   -> Fault Rejected: Temp Variation = 7.15°C
# Evaluating fault at 2024-01-10
#   + Included previous day (2024-01-09): -1.76°C
#   + Included next day     (2024-01-11): -2.35°C
#   -> Fault Detected: Temp Variation = 0.59°C
# Evaluating fault at 2024-01-13
#   + Included previous day (2024-01-12): -3.16°C
#   + Included next day     (2024-01-14): 1.34°C
#   -> Fault Detected: Temp Variation = 4.84°C
# Evaluating fault at 2024-01-14
#   + Included previous day (2024-01-13): 1.68°C
#   + Included next day     (2024-01-15): -4.74°C
#   -> Fault Rejected: Temp Variation = 6.42°C
# Evaluating fault at 2024-01-15
#   + Included previous day (2024-01-14): 1.34°C
#   + Included next day     (2024-01-16): -9.96°C
#   -> Fault Rejected: Temp Variation = 11.31°C
# Evaluating fault at 2024-01-16
#   + Included previous day (2024-01-15): -4.74°C
#   + Included next day     (2024-01-17): 0.17°C
#   -> Fault Rejected: Temp Variation = 10.13°C
# Evaluating fault at 2024-01-17
#   + Included previous day (2024-01-16): -9.96°C
#   + Included next day     (2024-01-18): -1.07°C
#   -> Fault Rejected: Temp Variation = 10.13°C
# Evaluating fault at 2024-01-20
#   + Included previous day (2024-01-19): 0.65°C
#   + Included next day     (2024-01-21): 1.68°C
#   -> Fault Detected: Temp Variation = 1.02°C
# Evaluating fault at 2024-01-23
#   + Included previous day (2024-01-22): 4.15°C
#   + Included next day     (2024-01-24): 4.97°C
#   -> Fault Detected: Temp Variation = 0.89°C
# Evaluating fault at 2024-01-25
#   + Included previous day (2024-01-24): 4.97°C
#   + Included next day     (2024-01-26): 3.11°C
#   -> Fault Detected: Temp Variation = 3.05°C
# Evaluating fault at 2024-01-27
#   + Included previous day (2024-01-26): 3.11°C
#   + Included next day     (2024-01-28): 3.65°C
#   -> Fault Detected: Temp Variation = 1.12°C
# Evaluating fault at 2024-02-03
#   + Included previous day (2024-02-02): 4.69°C
#   + Included next day     (2024-02-04): 5.54°C
#   -> Fault Detected: Temp Variation = 1.60°C
# Evaluating fault at 2024-02-04
#   + Included previous day (2024-02-03): 6.29°C
#   + Included next day     (2024-02-05): 4.34°C
#   -> Fault Detected: Temp Variation = 1.96°C
# Evaluating fault at 2024-02-09
#   + Included previous day (2024-02-08): 0.26°C
#   + Included next day     (2024-02-10): 0.71°C
#   -> Fault Detected: Temp Variation = 2.08°C
# Evaluating fault at 2024-02-10
#   + Included previous day (2024-02-09): -1.38°C
#   + Included next day     (2024-02-11): 1.21°C
#   -> Fault Detected: Temp Variation = 2.59°C
# Evaluating fault at 2024-02-13
#   + Included previous day (2024-02-12): 1.54°C
#   + Included next day     (2024-02-14): 4.52°C
#   -> Fault Detected: Temp Variation = 2.98°C
# Evaluating fault at 2024-02-16
#   + Included previous day (2024-02-15): 5.22°C
#   + Included next day     (2024-02-17): 4.01°C
#   -> Fault Detected: Temp Variation = 4.17°C
# Evaluating fault at 2024-02-17
#   + Included previous day (2024-02-16): 8.17°C
#   + Included next day     (2024-02-18): 2.52°C
#   -> Fault Rejected: Temp Variation = 5.65°C
# Evaluating fault at 2024-02-18
#   + Included previous day (2024-02-17): 4.01°C
#   + Included next day     (2024-02-19): 3.92°C
#   -> Fault Detected: Temp Variation = 1.49°C
# Evaluating fault at 2024-02-26
#   + Included previous day (2024-02-25): 5.59°C
#   + Included next day     (2024-02-27): 2.26°C
#   -> Fault Detected: Temp Variation = 3.33°C
# Evaluating fault at 2024-02-27
#   + Included previous day (2024-02-26): 4.41°C
#   + Included next day     (2024-02-28): 4.07°C
#   -> Fault Detected: Temp Variation = 2.15°C
# Evaluating fault at 2024-02-29
#   + Included previous day (2024-02-28): 4.07°C
#   + Included next day     (2024-03-01): 6.26°C
#   -> Fault Detected: Temp Variation = 2.20°C
# Evaluating fault at 2024-03-01
#   + Included previous day (2024-02-29): 5.76°C
#   + Included next day     (2024-03-02): 8.10°C
#   -> Fault Detected: Temp Variation = 2.34°C
# Evaluating fault at 2024-03-03
#   + Included previous day (2024-03-02): 8.10°C
#   + Included next day     (2024-03-04): 5.38°C
#   -> Fault Detected: Temp Variation = 2.72°C
# Evaluating fault at 2024-03-05
#   + Included previous day (2024-03-04): 5.38°C
#   + Included next day     (2024-03-06): 4.09°C
#   -> Fault Detected: Temp Variation = 1.67°C
# Evaluating fault at 2024-03-06
#   + Included previous day (2024-03-05): 3.71°C
#   + Included next day     (2024-03-07): 0.80°C
#   -> Fault Detected: Temp Variation = 3.29°C
# Evaluating fault at 2024-03-09
#   + Included previous day (2024-03-08): 2.50°C
#   + Included next day     (2024-03-10): 2.24°C
#   -> Fault Detected: Temp Variation = 0.78°C
# Evaluating fault at 2024-03-10
#   + Included previous day (2024-03-09): 1.73°C
#   + Included next day     (2024-03-11): 4.87°C
#   -> Fault Detected: Temp Variation = 3.14°C
# Evaluating fault at 2024-03-12
#   + Included previous day (2024-03-11): 4.87°C
#   + Included next day     (2024-03-13): 5.45°C
#   -> Fault Detected: Temp Variation = 0.89°C
# Evaluating fault at 2024-03-14
#   + Included previous day (2024-03-13): 5.45°C
#   + Included next day     (2024-03-15): 9.33°C
#   -> Fault Detected: Temp Variation = 3.88°C
# Evaluating fault at 2024-03-15
#   + Included previous day (2024-03-14): 7.73°C
#   + Included next day     (2024-03-16): 5.75°C
#   -> Fault Detected: Temp Variation = 3.58°C
# Evaluating fault at 2024-03-17
#   + Included previous day (2024-03-16): 5.75°C
#   + Included next day     (2024-03-18): 0.31°C
#   -> Fault Rejected: Temp Variation = 5.44°C
# Evaluating fault at 2024-03-22
#   + Included previous day (2024-03-21): 4.17°C
#   + Included next day     (2024-03-23): 5.45°C
#   -> Fault Detected: Temp Variation = 1.87°C
# Evaluating fault at 2024-03-23
#   + Included previous day (2024-03-22): 6.04°C
#   + Included next day     (2024-03-24): 5.28°C
#   -> Fault Detected: Temp Variation = 0.76°C
# Evaluating fault at 2024-03-25
#   + Included previous day (2024-03-24): 5.28°C
#   + Included next day     (2024-03-26): 4.94°C
#   -> Fault Detected: Temp Variation = 1.19°C
# Evaluating fault at 2024-03-26
#   + Included previous day (2024-03-25): 4.09°C
#   + Included next day     (2024-03-27): 9.49°C
#   -> Fault Rejected: Temp Variation = 5.40°C
# Evaluating fault at 2024-03-27
#   + Included previous day (2024-03-26): 4.94°C
#   + Included next day     (2024-03-28): 7.97°C
#   -> Fault Detected: Temp Variation = 4.55°C
# Evaluating fault at 2024-03-29
#   + Included previous day (2024-03-28): 7.97°C
#   + Included next day     (2024-03-30): 7.35°C
#   -> Fault Detected: Temp Variation = 0.62°C
# Evaluating fault at 2024-03-31
#   + Included previous day (2024-03-30): 7.35°C
#   + Included next day     (2024-04-01): 10.17°C
#   -> Fault Detected: Temp Variation = 2.82°C
# Evaluating fault at 2024-04-02
#   + Included previous day (2024-04-01): 10.17°C
#   + Included next day     (2024-04-03): -0.01°C
#   -> Fault Rejected: Temp Variation = 10.17°C
# Evaluating fault at 2024-04-03
#   + Included previous day (2024-04-02): 2.88°C
#   + Included next day     (2024-04-04): 1.85°C
#   -> Fault Detected: Temp Variation = 2.89°C
# Evaluating fault at 2024-04-04
#   + Included previous day (2024-04-03): -0.01°C
#   + Included next day     (2024-04-05): 6.98°C
#   -> Fault Rejected: Temp Variation = 6.99°C
# Evaluating fault at 2024-04-05
#   + Included previous day (2024-04-04): 1.85°C
#   + Included next day     (2024-04-06): 9.74°C
#   -> Fault Rejected: Temp Variation = 7.90°C
# Evaluating fault at 2024-04-06
#   + Included previous day (2024-04-05): 6.98°C
#   + Included next day     (2024-04-07): 11.95°C
#   -> Fault Detected: Temp Variation = 4.97°C
# Evaluating fault at 2024-04-07
#   + Included previous day (2024-04-06): 9.74°C
#   + Included next day     (2024-04-08): 12.18°C
#   -> Fault Detected: Temp Variation = 2.44°C
# Evaluating fault at 2024-04-08
#   + Included previous day (2024-04-07): 11.95°C
#   + Included next day     (2024-04-09): 12.70°C
#   -> Fault Detected: Temp Variation = 0.75°C
# Evaluating fault at 2024-04-09
#   + Included previous day (2024-04-08): 12.18°C
#   + Included next day     (2024-04-10): 8.63°C
#   -> Fault Detected: Temp Variation = 4.07°C
# Evaluating fault at 2024-04-10
#   + Included previous day (2024-04-09): 12.70°C
#   + Included next day     (2024-04-11): 8.86°C
#   -> Fault Detected: Temp Variation = 4.07°C
# Evaluating fault at 2024-04-12
#   + Included previous day (2024-04-11): 8.86°C
#   + Included next day     (2024-04-13): 9.74°C
#   -> Fault Detected: Temp Variation = 1.00°C
# Evaluating fault at 2024-04-13
#   + Included previous day (2024-04-12): 8.74°C
#   + Included next day     (2024-04-14): 8.60°C
#   -> Fault Detected: Temp Variation = 1.15°C
# Evaluating fault at 2024-04-14
#   + Included previous day (2024-04-13): 9.74°C
#   + Included next day     (2024-04-15): 7.67°C
#   -> Fault Detected: Temp Variation = 2.08°C
# Evaluating fault at 2024-04-17
#   + Included previous day (2024-04-16): 6.30°C
#   + Included next day     (2024-04-18): 5.79°C
#   -> Fault Detected: Temp Variation = 0.98°C
# Evaluating fault at 2024-04-19
#   + Included previous day (2024-04-18): 5.79°C
#   + Included next day     (2024-04-20): 3.13°C
#   -> Fault Detected: Temp Variation = 2.65°C
# Evaluating fault at 2024-04-22
#   + Included previous day (2024-04-21): 4.27°C
#   + Included next day     (2024-04-23): 2.71°C
#   -> Fault Detected: Temp Variation = 3.40°C
# Evaluating fault at 2024-04-23
#   + Included previous day (2024-04-22): 0.87°C
#   + Included next day     (2024-04-24): 4.89°C
#   -> Fault Detected: Temp Variation = 4.01°C
# Evaluating fault at 2024-04-28
#   + Included previous day (2024-04-27): 8.26°C
#   + Included next day     (2024-04-29): 11.44°C
#   -> Fault Rejected: Temp Variation = 7.03°C
# Evaluating fault at 2024-04-29
#   + Included previous day (2024-04-28): 15.29°C
#   + Included next day     (2024-04-30): 15.00°C
#   -> Fault Detected: Temp Variation = 3.85°C
# Evaluating fault at 2024-04-30
#   + Included previous day (2024-04-29): 11.44°C
#   + Included next day     (2024-05-01): 18.45°C
#   -> Fault Rejected: Temp Variation = 7.01°C
# Evaluating fault at 2024-05-02
#   + Included previous day (2024-05-01): 18.45°C
#   + Included next day     (2024-05-03): 17.80°C
#   -> Fault Detected: Temp Variation = 0.64°C
# Evaluating fault at 2024-05-03
#   + Included previous day (2024-05-02): 18.23°C
#   + Included next day     (2024-05-04): 12.98°C
#   -> Fault Rejected: Temp Variation = 5.25°C
# Evaluating fault at 2024-05-04
#   + Included previous day (2024-05-03): 17.80°C
#   + Included next day     (2024-05-05): 13.38°C
#   -> Fault Detected: Temp Variation = 4.83°C
# Evaluating fault at 2024-05-05
#   + Included previous day (2024-05-04): 12.98°C
#   + Included next day     (2024-05-06): 10.75°C
#   -> Fault Detected: Temp Variation = 2.64°C
# Evaluating fault at 2024-05-06
#   + Included previous day (2024-05-05): 13.38°C
#   + Included next day     (2024-05-07): 10.16°C
#   -> Fault Detected: Temp Variation = 3.23°C
# Evaluating fault at 2024-05-07
#   + Included previous day (2024-05-06): 10.75°C
#   + Included next day     (2024-05-08): 11.34°C
#   -> Fault Detected: Temp Variation = 1.18°C
# Evaluating fault at 2024-05-09
#   + Included previous day (2024-05-08): 11.34°C
#   + Included next day     (2024-05-10): 11.46°C
#   -> Fault Detected: Temp Variation = 0.18°C
# Evaluating fault at 2024-05-10
#   + Included previous day (2024-05-09): 11.52°C
#   + Included next day     (2024-05-11): 12.56°C
#   -> Fault Detected: Temp Variation = 1.10°C
# Evaluating fault at 2024-05-11
#   + Included previous day (2024-05-10): 11.46°C
#   + Included next day     (2024-05-12): 12.42°C
#   -> Fault Detected: Temp Variation = 1.10°C
# Evaluating fault at 2024-05-12
#   + Included previous day (2024-05-11): 12.56°C
#   + Included next day     (2024-05-13): 14.65°C
#   -> Fault Detected: Temp Variation = 2.23°C
# Evaluating fault at 2024-05-13
#   + Included previous day (2024-05-12): 12.42°C
#   + Included next day     (2024-05-14): 16.61°C
#   -> Fault Detected: Temp Variation = 4.19°C
# Evaluating fault at 2024-05-14
#   + Included previous day (2024-05-13): 14.65°C
#   + Included next day     (2024-05-15): 17.76°C
#   -> Fault Detected: Temp Variation = 3.11°C
# Evaluating fault at 2024-05-15
#   + Included previous day (2024-05-14): 16.61°C
#   + Included next day     (2024-05-16): 17.14°C
#   -> Fault Detected: Temp Variation = 1.15°C
# Evaluating fault at 2024-05-17
#   + Included previous day (2024-05-16): 17.14°C
#   + Included next day     (2024-05-18): 18.05°C
#   -> Fault Detected: Temp Variation = 0.91°C
# Evaluating fault at 2024-05-18
#   + Included previous day (2024-05-17): 17.34°C
#   + Included next day     (2024-05-19): 17.93°C
#   -> Fault Detected: Temp Variation = 0.71°C
# Evaluating fault at 2024-05-20
#   + Included previous day (2024-05-19): 17.93°C
#   + Included next day     (2024-05-21): 18.20°C
#   -> Fault Detected: Temp Variation = 0.44°C
# Evaluating fault at 2024-06-09
#   + Included previous day (2024-06-08): 12.29°C
#   + Included next day     (2024-06-10): 13.39°C
#   -> Fault Detected: Temp Variation = 1.58°C
# Evaluating fault at 2024-06-10
#   + Included previous day (2024-06-09): 11.81°C
#   + Included next day     (2024-06-11): 12.90°C
#   -> Fault Detected: Temp Variation = 1.58°C
# Evaluating fault at 2024-06-12
#   + Included previous day (2024-06-11): 12.90°C
#   + Included next day     (2024-06-13): 11.69°C
#   -> Fault Detected: Temp Variation = 1.21°C
# Evaluating fault at 2024-06-15
#   + Included previous day (2024-06-14): 13.91°C
#   + Included next day     (2024-06-16): 16.04°C
#   -> Fault Detected: Temp Variation = 2.13°C
# Evaluating fault at 2024-06-16
#   + Included previous day (2024-06-15): 14.32°C
#   + Included next day     (2024-06-17): 15.85°C
#   -> Fault Detected: Temp Variation = 1.71°C
# Evaluating fault at 2024-06-18
#   + Included previous day (2024-06-17): 15.85°C
#   + Included next day     (2024-06-19): 14.54°C
#   -> Fault Detected: Temp Variation = 1.31°C
# Evaluating fault at 2024-06-19
#   + Included previous day (2024-06-18): 14.73°C
#   + Included next day     (2024-06-20): 15.13°C
#   -> Fault Detected: Temp Variation = 0.59°C
# Evaluating fault at 2024-06-20
#   + Included previous day (2024-06-19): 14.54°C
#   + Included next day     (2024-06-21): 16.32°C
#   -> Fault Detected: Temp Variation = 1.78°C
# Evaluating fault at 2024-06-21
#   + Included previous day (2024-06-20): 15.13°C
#   + Included next day     (2024-06-22): 14.16°C
#   -> Fault Detected: Temp Variation = 2.17°C
# Evaluating fault at 2024-06-22
#   + Included previous day (2024-06-21): 16.32°C
#   + Included next day     (2024-06-23): 15.36°C
#   -> Fault Detected: Temp Variation = 2.17°C
# Evaluating fault at 2024-06-23
#   + Included previous day (2024-06-22): 14.16°C
#   + Included next day     (2024-06-24): 15.52°C
#   -> Fault Detected: Temp Variation = 1.36°C
# Evaluating fault at 2024-06-24
#   + Included previous day (2024-06-23): 15.36°C
#   + Included next day     (2024-06-25): 17.17°C
#   -> Fault Detected: Temp Variation = 1.81°C
# Evaluating fault at 2024-06-27
#   + Included previous day (2024-06-26): 20.12°C
#   + Included next day     (2024-06-28): 19.45°C
#   -> Fault Detected: Temp Variation = 3.72°C
# Evaluating fault at 2024-07-07
#   + Included previous day (2024-07-06): 15.71°C
#   + Included next day     (2024-07-08): 15.42°C
#   -> Fault Detected: Temp Variation = 0.29°C
# Evaluating fault at 2024-08-03
#   + Included previous day (2024-08-02): 15.84°C
#   + Included next day     (2024-08-04): 17.16°C
#   -> Fault Detected: Temp Variation = 1.32°C
# Evaluating fault at 2024-09-25
#   + Included previous day (2024-09-24): 15.26°C
#   + Included next day     (2024-09-26): 13.27°C
#   -> Fault Detected: Temp Variation = 1.99°C
# Evaluating fault at 2024-09-26
#   + Included previous day (2024-09-25): 15.21°C
#   + Included next day     (2024-09-27): 13.20°C
#   -> Fault Detected: Temp Variation = 2.01°C
# Evaluating fault at 2024-09-27
#   + Included previous day (2024-09-26): 13.27°C
#   + Included next day     (2024-09-28): 10.75°C
#   -> Fault Detected: Temp Variation = 2.52°C
# Evaluating fault at 2024-09-28
#   + Included previous day (2024-09-27): 13.20°C
#   + Included next day     (2024-09-29): 11.29°C
#   -> Fault Detected: Temp Variation = 2.45°C
# Evaluating fault at 2024-09-29
#   + Included previous day (2024-09-28): 10.75°C
#   + Included next day     (2024-09-30): 10.61°C
#   -> Fault Detected: Temp Variation = 0.69°C
# Evaluating fault at 2024-09-30
#   + Included previous day (2024-09-29): 11.29°C
#   + Included next day     (2024-10-01): 10.28°C
#   -> Fault Detected: Temp Variation = 1.01°C
# Evaluating fault at 2024-10-05
#   + Included previous day (2024-10-04): 8.27°C
#   + Included next day     (2024-10-06): 9.91°C
#   -> Fault Detected: Temp Variation = 1.64°C
# Evaluating fault at 2024-10-07
#   + Included previous day (2024-10-06): 9.91°C
#   + Included next day     (2024-10-08): 13.18°C
#   -> Fault Detected: Temp Variation = 3.28°C
# Evaluating fault at 2024-10-09
#   + Included previous day (2024-10-08): 13.18°C
#   + Included next day     (2024-10-10): 12.50°C
#   -> Fault Detected: Temp Variation = 1.09°C
# Evaluating fault at 2024-10-10
#   + Included previous day (2024-10-09): 13.59°C
#   + Included next day     (2024-10-11): 11.04°C
#   -> Fault Detected: Temp Variation = 2.55°C
# Evaluating fault at 2024-10-12
#   + Included previous day (2024-10-11): 11.04°C
#   + Included next day     (2024-10-13): 10.14°C
#   -> Fault Detected: Temp Variation = 0.90°C
# Evaluating fault at 2024-10-15
#   + Included previous day (2024-10-14): 8.54°C
#   + Included next day     (2024-10-16): 7.95°C
#   -> Fault Detected: Temp Variation = 3.71°C
# Evaluating fault at 2024-10-17
#   + Included previous day (2024-10-16): 7.95°C
#   + Included next day     (2024-10-18): 12.72°C
#   -> Fault Detected: Temp Variation = 4.78°C
# Evaluating fault at 2024-10-18
#   + Included previous day (2024-10-17): 11.14°C
#   + Included next day     (2024-10-19): 12.56°C
#   -> Fault Detected: Temp Variation = 1.58°C
# Evaluating fault at 2024-10-19
#   + Included previous day (2024-10-18): 12.72°C
#   + Included next day     (2024-10-20): 14.28°C
#   -> Fault Detected: Temp Variation = 1.73°C
# Evaluating fault at 2024-10-20
#   + Included previous day (2024-10-19): 12.56°C
#   + Included next day     (2024-10-21): 13.83°C
#   -> Fault Detected: Temp Variation = 1.73°C
# Evaluating fault at 2024-10-21
#   + Included previous day (2024-10-20): 14.28°C
#   + Included next day     (2024-10-22): 12.55°C
#   -> Fault Detected: Temp Variation = 1.73°C
# Evaluating fault at 2024-10-23
#   + Included previous day (2024-10-22): 12.55°C
#   + Included next day     (2024-10-24): 10.38°C
#   -> Fault Detected: Temp Variation = 2.18°C
# Evaluating fault at 2024-10-24
#   + Included previous day (2024-10-23): 12.10°C
#   + Included next day     (2024-10-25): 10.02°C
#   -> Fault Detected: Temp Variation = 2.08°C
# Evaluating fault at 2024-10-26
#   + Included previous day (2024-10-25): 10.02°C
#   + Included next day     (2024-10-27): 11.32°C
#   -> Fault Detected: Temp Variation = 1.39°C
# Evaluating fault at 2024-10-27
#   + Included previous day (2024-10-26): 11.40°C
#   + Included next day     (2024-10-28): 11.31°C
#   -> Fault Detected: Temp Variation = 0.09°C
# Evaluating fault at 2024-10-28
#   + Included previous day (2024-10-27): 11.32°C
#   + Included next day     (2024-10-29): 11.71°C
#   -> Fault Detected: Temp Variation = 0.40°C
# TP=14, FP=96, precision=0.127
# True Positives  (TP): 14
# False Positives (FP): 96
# Precision         : 0.127
# TP=14, FP=96, FN=16
# Precision = 0.127
# Recall = 0.467
#
# ==============================
# Processing dataset:
# ==============================
# Dataset '': Process Mean = 0.001, UCL = 0.015, LCL = -0.013
# Evaluating fault at 2023-11-30
#   + Included next day     (2023-12-01): -3.23°C
#   -> Fault Detected: Temp Variation = 0.68°C
# Evaluating fault at 2023-12-01
#   + Included previous day (2023-11-30): -3.92°C
#   + Included next day     (2023-12-02): -6.91°C
#   -> Fault Detected: Temp Variation = 3.68°C
# Evaluating fault at 2023-12-05
#   + Included previous day (2023-12-04): -4.49°C
#   + Included next day     (2023-12-06): 0.46°C
#   -> Fault Detected: Temp Variation = 4.95°C
# Evaluating fault at 2023-12-13
#   + Included previous day (2023-12-12): -0.06°C
#   + Included next day     (2023-12-14): -1.07°C
#   -> Fault Detected: Temp Variation = 1.62°C
# Evaluating fault at 2023-12-14
#   + Included previous day (2023-12-13): -1.68°C
#   + Included next day     (2023-12-15): 2.58°C
#   -> Fault Detected: Temp Variation = 4.27°C
# Evaluating fault at 2023-12-15
#   + Included previous day (2023-12-14): -1.07°C
#   + Included next day     (2023-12-16): 5.32°C
#   -> Fault Rejected: Temp Variation = 6.39°C
# Evaluating fault at 2023-12-16
#   + Included previous day (2023-12-15): 2.58°C
#   + Included next day     (2023-12-17): 5.95°C
#   -> Fault Detected: Temp Variation = 3.36°C
# Evaluating fault at 2023-12-17
#   + Included previous day (2023-12-16): 5.32°C
#   + Included next day     (2023-12-18): 5.99°C
#   -> Fault Detected: Temp Variation = 0.67°C
# Evaluating fault at 2023-12-20
#   + Included previous day (2023-12-19): 5.28°C
#   + Included next day     (2023-12-21): 3.78°C
#   -> Fault Detected: Temp Variation = 1.50°C
# Evaluating fault at 2023-12-22
#   + Included previous day (2023-12-21): 3.78°C
#   + Included next day     (2023-12-23): -2.78°C
#   -> Fault Rejected: Temp Variation = 6.55°C
# Evaluating fault at 2023-12-23
#   + Included previous day (2023-12-22): 0.36°C
#   + Included next day     (2023-12-24): 0.80°C
#   -> Fault Detected: Temp Variation = 3.57°C
# Evaluating fault at 2023-12-25
#   + Included previous day (2023-12-24): 0.80°C
#   + Included next day     (2023-12-26): 3.06°C
#   -> Fault Detected: Temp Variation = 4.68°C
# Evaluating fault at 2023-12-28
#   + Included previous day (2023-12-27): 1.06°C
#   + Included next day     (2023-12-29): 5.84°C
#   -> Fault Detected: Temp Variation = 4.78°C
# Evaluating fault at 2023-12-30
#   + Included previous day (2023-12-29): 5.84°C
#   + Included next day     (2023-12-31): 3.79°C
#   -> Fault Detected: Temp Variation = 2.06°C
# Evaluating fault at 2023-12-31
#   + Included previous day (2023-12-30): 4.50°C
#   + Included next day     (2024-01-01): 2.73°C
#   -> Fault Detected: Temp Variation = 1.78°C
# Evaluating fault at 2024-01-02
#   + Included previous day (2024-01-01): 2.73°C
#   + Included next day     (2024-01-03): -2.61°C
#   -> Fault Rejected: Temp Variation = 5.33°C
# Evaluating fault at 2024-01-04
#   + Included previous day (2024-01-03): -2.61°C
#   + Included next day     (2024-01-05): -11.29°C
#   -> Fault Rejected: Temp Variation = 8.69°C
# Evaluating fault at 2024-01-07
#   + Included previous day (2024-01-06): -11.58°C
#   + Included next day     (2024-01-08): -8.30°C
#   -> Fault Detected: Temp Variation = 3.28°C
# Evaluating fault at 2024-01-08
#   + Included previous day (2024-01-07): -8.91°C
#   + Included next day     (2024-01-09): -1.76°C
#   -> Fault Rejected: Temp Variation = 7.15°C
# Evaluating fault at 2024-01-09
#   + Included previous day (2024-01-08): -8.30°C
#   + Included next day     (2024-01-10): -1.92°C
#   -> Fault Rejected: Temp Variation = 6.54°C
# Evaluating fault at 2024-01-10
#   + Included previous day (2024-01-09): -1.76°C
#   + Included next day     (2024-01-11): -2.35°C
#   -> Fault Detected: Temp Variation = 0.59°C
# Evaluating fault at 2024-01-13
#   + Included previous day (2024-01-12): -3.16°C
#   + Included next day     (2024-01-14): 1.34°C
#   -> Fault Detected: Temp Variation = 4.84°C
# Evaluating fault at 2024-01-14
#   + Included previous day (2024-01-13): 1.68°C
#   + Included next day     (2024-01-15): -4.74°C
#   -> Fault Rejected: Temp Variation = 6.42°C
# Evaluating fault at 2024-01-15
#   + Included previous day (2024-01-14): 1.34°C
#   + Included next day     (2024-01-16): -9.96°C
#   -> Fault Rejected: Temp Variation = 11.31°C
# Evaluating fault at 2024-01-16
#   + Included previous day (2024-01-15): -4.74°C
#   + Included next day     (2024-01-17): 0.17°C
#   -> Fault Rejected: Temp Variation = 10.13°C
# Evaluating fault at 2024-01-18
#   + Included previous day (2024-01-17): 0.17°C
#   + Included next day     (2024-01-19): 0.65°C
#   -> Fault Detected: Temp Variation = 1.73°C
# Evaluating fault at 2024-01-19
#   + Included previous day (2024-01-18): -1.07°C
#   + Included next day     (2024-01-20): 0.93°C
#   -> Fault Detected: Temp Variation = 2.00°C
# Evaluating fault at 2024-01-20
#   + Included previous day (2024-01-19): 0.65°C
#   + Included next day     (2024-01-21): 1.68°C
#   -> Fault Detected: Temp Variation = 1.02°C
# Evaluating fault at 2024-01-22
#   + Included previous day (2024-01-21): 1.68°C
#   + Included next day     (2024-01-23): 4.08°C
#   -> Fault Detected: Temp Variation = 2.48°C
# Evaluating fault at 2024-01-24
#   + Included previous day (2024-01-23): 4.08°C
#   + Included next day     (2024-01-25): 1.92°C
#   -> Fault Detected: Temp Variation = 3.05°C
# Evaluating fault at 2024-01-26
#   + Included previous day (2024-01-25): 1.92°C
#   + Included next day     (2024-01-27): 4.23°C
#   -> Fault Detected: Temp Variation = 2.30°C
# Evaluating fault at 2024-02-04
#   + Included previous day (2024-02-03): 6.29°C
#   + Included next day     (2024-02-05): 4.34°C
#   -> Fault Detected: Temp Variation = 1.96°C
# Evaluating fault at 2024-02-12
#   + Included previous day (2024-02-11): 1.21°C
#   + Included next day     (2024-02-13): 3.25°C
#   -> Fault Detected: Temp Variation = 2.04°C
# Evaluating fault at 2024-02-14
#   + Included previous day (2024-02-13): 3.25°C
#   + Included next day     (2024-02-15): 5.22°C
#   -> Fault Detected: Temp Variation = 1.97°C
# Evaluating fault at 2024-02-16
#   + Included previous day (2024-02-15): 5.22°C
#   + Included next day     (2024-02-17): 4.01°C
#   -> Fault Detected: Temp Variation = 4.17°C
# Evaluating fault at 2024-02-17
#   + Included previous day (2024-02-16): 8.17°C
#   + Included next day     (2024-02-18): 2.52°C
#   -> Fault Rejected: Temp Variation = 5.65°C
# Evaluating fault at 2024-02-19
#   + Included previous day (2024-02-18): 2.52°C
#   + Included next day     (2024-02-20): 4.84°C
#   -> Fault Detected: Temp Variation = 2.32°C
# Evaluating fault at 2024-02-23
#   + Included previous day (2024-02-22): 6.36°C
#   + Included next day     (2024-02-24): 5.70°C
#   -> Fault Detected: Temp Variation = 0.96°C
# Evaluating fault at 2024-02-26
#   + Included previous day (2024-02-25): 5.59°C
#   + Included next day     (2024-02-27): 2.26°C
#   -> Fault Detected: Temp Variation = 3.33°C
# Evaluating fault at 2024-02-27
#   + Included previous day (2024-02-26): 4.41°C
#   + Included next day     (2024-02-28): 4.07°C
#   -> Fault Detected: Temp Variation = 2.15°C
# Evaluating fault at 2024-02-29
#   + Included previous day (2024-02-28): 4.07°C
#   + Included next day     (2024-03-01): 6.26°C
#   -> Fault Detected: Temp Variation = 2.20°C
# Evaluating fault at 2024-03-04
#   + Included previous day (2024-03-03): 7.69°C
#   + Included next day     (2024-03-05): 3.71°C
#   -> Fault Detected: Temp Variation = 3.97°C
# Evaluating fault at 2024-03-05
#   + Included previous day (2024-03-04): 5.38°C
#   + Included next day     (2024-03-06): 4.09°C
#   -> Fault Detected: Temp Variation = 1.67°C
# Evaluating fault at 2024-03-06
#   + Included previous day (2024-03-05): 3.71°C
# ...
#   + Included next day     (2024-01-02): -0.76°C
#   -> Fault Detected: Temp Variation = 4.55°C
# Evaluating fault at 2024-01-02
#   + Included previous day (2024-01-01): 2.73°C
#   + Included next day     (2024-01-03): -2.61°C
#   -> Fault Rejected: Temp Variation = 5.33°C
# Evaluating fault at 2024-01-03
#   + Included previous day (2024-01-02): -0.76°C
#   + Included next day     (2024-01-04): -5.69°C
#   -> Fault Detected: Temp Variation = 4.92°C
# Evaluating fault at 2024-01-04
#   + Included previous day (2024-01-03): -2.61°C
#   + Included next day     (2024-01-05): -11.29°C
#   -> Fault Rejected: Temp Variation = 8.69°C
# Evaluating fault at 2024-01-05
#   + Included previous day (2024-01-04): -5.69°C
#   + Included next day     (2024-01-06): -11.58°C
#   -> Fault Rejected: Temp Variation = 5.89°C
# Evaluating fault at 2024-01-08
#   + Included previous day (2024-01-07): -8.91°C
#   + Included next day     (2024-01-09): -1.76°C
#   -> Fault Rejected: Temp Variation = 7.15°C
# Evaluating fault at 2024-01-10
#   + Included previous day (2024-01-09): -1.76°C
#   + Included next day     (2024-01-11): -2.35°C
#   -> Fault Detected: Temp Variation = 0.59°C
# Evaluating fault at 2024-01-11
#   + Included previous day (2024-01-10): -1.92°C
#   + Included next day     (2024-01-12): -3.16°C
#   -> Fault Detected: Temp Variation = 1.25°C
# Evaluating fault at 2024-01-15
#   + Included previous day (2024-01-14): 1.34°C
#   + Included next day     (2024-01-16): -9.96°C
#   -> Fault Rejected: Temp Variation = 11.31°C
# Evaluating fault at 2024-01-17
#   + Included previous day (2024-01-16): -9.96°C
#   + Included next day     (2024-01-18): -1.07°C
#   -> Fault Rejected: Temp Variation = 10.13°C
# Evaluating fault at 2024-01-18
#   + Included previous day (2024-01-17): 0.17°C
#   + Included next day     (2024-01-19): 0.65°C
#   -> Fault Detected: Temp Variation = 1.73°C
# Evaluating fault at 2024-01-20
#   + Included previous day (2024-01-19): 0.65°C
#   + Included next day     (2024-01-21): 1.68°C
#   -> Fault Detected: Temp Variation = 1.02°C
# Evaluating fault at 2024-02-03
#   + Included previous day (2024-02-02): 4.69°C
#   + Included next day     (2024-02-04): 5.54°C
#   -> Fault Detected: Temp Variation = 1.60°C
# Evaluating fault at 2024-02-09
#   + Included previous day (2024-02-08): 0.26°C
#   + Included next day     (2024-02-10): 0.71°C
#   -> Fault Detected: Temp Variation = 2.08°C
# Evaluating fault at 2024-02-10
#   + Included previous day (2024-02-09): -1.38°C
#   + Included next day     (2024-02-11): 1.21°C
#   -> Fault Detected: Temp Variation = 2.59°C
# Evaluating fault at 2024-02-11
#   + Included previous day (2024-02-10): 0.71°C
#   + Included next day     (2024-02-12): 1.54°C
#   -> Fault Detected: Temp Variation = 0.83°C
# Evaluating fault at 2024-02-12
#   + Included previous day (2024-02-11): 1.21°C
#   + Included next day     (2024-02-13): 3.25°C
#   -> Fault Detected: Temp Variation = 2.04°C
# Evaluating fault at 2024-02-14
#   + Included previous day (2024-02-13): 3.25°C
#   + Included next day     (2024-02-15): 5.22°C
#   -> Fault Detected: Temp Variation = 1.97°C
# Evaluating fault at 2024-02-15
#   + Included previous day (2024-02-14): 4.52°C
#   + Included next day     (2024-02-16): 8.17°C
#   -> Fault Detected: Temp Variation = 3.65°C
# Evaluating fault at 2024-02-16
#   + Included previous day (2024-02-15): 5.22°C
#   + Included next day     (2024-02-17): 4.01°C
#   -> Fault Detected: Temp Variation = 4.17°C
# Evaluating fault at 2024-02-23
#   + Included previous day (2024-02-22): 6.36°C
#   + Included next day     (2024-02-24): 5.70°C
#   -> Fault Detected: Temp Variation = 0.96°C
# Evaluating fault at 2024-02-26
#   + Included previous day (2024-02-25): 5.59°C
#   + Included next day     (2024-02-27): 2.26°C
#   -> Fault Detected: Temp Variation = 3.33°C
# Evaluating fault at 2024-02-27
#   + Included previous day (2024-02-26): 4.41°C
#   + Included next day     (2024-02-28): 4.07°C
#   -> Fault Detected: Temp Variation = 2.15°C
# Evaluating fault at 2024-02-28
#   + Included previous day (2024-02-27): 2.26°C
#   + Included next day     (2024-02-29): 5.76°C
#   -> Fault Detected: Temp Variation = 3.50°C
# Evaluating fault at 2024-03-04
#   + Included previous day (2024-03-03): 7.69°C
#   + Included next day     (2024-03-05): 3.71°C
#   -> Fault Detected: Temp Variation = 3.97°C
# Evaluating fault at 2024-03-07
#   + Included previous day (2024-03-06): 4.09°C
#   + Included next day     (2024-03-08): 2.50°C
#   -> Fault Detected: Temp Variation = 3.29°C
# Evaluating fault at 2024-03-14
#   + Included previous day (2024-03-13): 5.45°C
#   + Included next day     (2024-03-15): 9.33°C
#   -> Fault Detected: Temp Variation = 3.88°C
# Evaluating fault at 2024-03-15
#   + Included previous day (2024-03-14): 7.73°C
#   + Included next day     (2024-03-16): 5.75°C
#   -> Fault Detected: Temp Variation = 3.58°C
# Evaluating fault at 2024-03-17
#   + Included previous day (2024-03-16): 5.75°C
#   + Included next day     (2024-03-18): 0.31°C
#   -> Fault Rejected: Temp Variation = 5.44°C
# Evaluating fault at 2024-03-18
#   + Included previous day (2024-03-17): 1.93°C
#   + Included next day     (2024-03-19): 2.20°C
#   -> Fault Detected: Temp Variation = 1.89°C
# Evaluating fault at 2024-03-23
#   + Included previous day (2024-03-22): 6.04°C
#   + Included next day     (2024-03-24): 5.28°C
#   -> Fault Detected: Temp Variation = 0.76°C
# Evaluating fault at 2024-03-24
#   + Included previous day (2024-03-23): 5.45°C
#   + Included next day     (2024-03-25): 4.09°C
#   -> Fault Detected: Temp Variation = 1.35°C
# Evaluating fault at 2024-03-27
#   + Included previous day (2024-03-26): 4.94°C
#   + Included next day     (2024-03-28): 7.97°C
#   -> Fault Detected: Temp Variation = 4.55°C
# Evaluating fault at 2024-03-28
#   + Included previous day (2024-03-27): 9.49°C
#   + Included next day     (2024-03-29): 7.50°C
#   -> Fault Detected: Temp Variation = 1.99°C
# Evaluating fault at 2024-03-29
#   + Included previous day (2024-03-28): 7.97°C
#   + Included next day     (2024-03-30): 7.35°C
#   -> Fault Detected: Temp Variation = 0.62°C
# Evaluating fault at 2024-03-30
#   + Included previous day (2024-03-29): 7.50°C
#   + Included next day     (2024-03-31): 8.63°C
#   -> Fault Detected: Temp Variation = 1.28°C
# Evaluating fault at 2024-03-31
#   + Included previous day (2024-03-30): 7.35°C
#   + Included next day     (2024-04-01): 10.17°C
#   -> Fault Detected: Temp Variation = 2.82°C
# Evaluating fault at 2024-04-02
#   + Included previous day (2024-04-01): 10.17°C
#   + Included next day     (2024-04-03): -0.01°C
#   -> Fault Rejected: Temp Variation = 10.17°C
# Evaluating fault at 2024-04-03
#   + Included previous day (2024-04-02): 2.88°C
#   + Included next day     (2024-04-04): 1.85°C
#   -> Fault Detected: Temp Variation = 2.89°C
# Evaluating fault at 2024-04-04
#   + Included previous day (2024-04-03): -0.01°C
#   + Included next day     (2024-04-05): 6.98°C
#   -> Fault Rejected: Temp Variation = 6.99°C
# Evaluating fault at 2024-04-06
#   + Included previous day (2024-04-05): 6.98°C
#   + Included next day     (2024-04-07): 11.95°C
#   -> Fault Detected: Temp Variation = 4.97°C
# Evaluating fault at 2024-04-07
#   + Included previous day (2024-04-06): 9.74°C
#   + Included next day     (2024-04-08): 12.18°C
#   -> Fault Detected: Temp Variation = 2.44°C
# Evaluating fault at 2024-04-08
#   + Included previous day (2024-04-07): 11.95°C
#   + Included next day     (2024-04-09): 12.70°C
#   -> Fault Detected: Temp Variation = 0.75°C
# Evaluating fault at 2024-04-09
#   + Included previous day (2024-04-08): 12.18°C
#   + Included next day     (2024-04-10): 8.63°C
#   -> Fault Detected: Temp Variation = 4.07°C
# Evaluating fault at 2024-04-12
#   + Included previous day (2024-04-11): 8.86°C
#   + Included next day     (2024-04-13): 9.74°C
#   -> Fault Detected: Temp Variation = 1.00°C
# Evaluating fault at 2024-04-13
#   + Included previous day (2024-04-12): 8.74°C
#   + Included next day     (2024-04-14): 8.60°C
#   -> Fault Detected: Temp Variation = 1.15°C
# Evaluating fault at 2024-04-19
#   + Included previous day (2024-04-18): 5.79°C
#   + Included next day     (2024-04-20): 3.13°C
#   -> Fault Detected: Temp Variation = 2.65°C
# Evaluating fault at 2024-04-22
#   + Included previous day (2024-04-21): 4.27°C
#   + Included next day     (2024-04-23): 2.71°C
#   -> Fault Detected: Temp Variation = 3.40°C
# Evaluating fault at 2024-04-28
#   + Included previous day (2024-04-27): 8.26°C
#   + Included next day     (2024-04-29): 11.44°C
#   -> Fault Rejected: Temp Variation = 7.03°C
# Evaluating fault at 2024-04-30
#   + Included previous day (2024-04-29): 11.44°C
#   + Included next day     (2024-05-01): 18.45°C
#   -> Fault Rejected: Temp Variation = 7.01°C
# Evaluating fault at 2024-05-01
#   + Included previous day (2024-04-30): 15.00°C
#   + Included next day     (2024-05-02): 18.23°C
#   -> Fault Detected: Temp Variation = 3.45°C
# Evaluating fault at 2024-05-02
#   + Included previous day (2024-05-01): 18.45°C
#   + Included next day     (2024-05-03): 17.80°C
#   -> Fault Detected: Temp Variation = 0.64°C
# Evaluating fault at 2024-05-03
#   + Included previous day (2024-05-02): 18.23°C
#   + Included next day     (2024-05-04): 12.98°C
#   -> Fault Rejected: Temp Variation = 5.25°C
# Evaluating fault at 2024-05-04
#   + Included previous day (2024-05-03): 17.80°C
#   + Included next day     (2024-05-05): 13.38°C
#   -> Fault Detected: Temp Variation = 4.83°C
# Evaluating fault at 2024-05-05
#   + Included previous day (2024-05-04): 12.98°C
#   + Included next day     (2024-05-06): 10.75°C
#   -> Fault Detected: Temp Variation = 2.64°C
# Evaluating fault at 2024-05-06
#   + Included previous day (2024-05-05): 13.38°C
#   + Included next day     (2024-05-07): 10.16°C
#   -> Fault Detected: Temp Variation = 3.23°C
# Evaluating fault at 2024-05-07
#   + Included previous day (2024-05-06): 10.75°C
#   + Included next day     (2024-05-08): 11.34°C
#   -> Fault Detected: Temp Variation = 1.18°C
# Evaluating fault at 2024-05-08
#   + Included previous day (2024-05-07): 10.16°C
#   + Included next day     (2024-05-09): 11.52°C
#   -> Fault Detected: Temp Variation = 1.36°C
# Evaluating fault at 2024-05-09
#   + Included previous day (2024-05-08): 11.34°C
#   + Included next day     (2024-05-10): 11.46°C
#   -> Fault Detected: Temp Variation = 0.18°C
# Evaluating fault at 2024-05-10
#   + Included previous day (2024-05-09): 11.52°C
#   + Included next day     (2024-05-11): 12.56°C
#   -> Fault Detected: Temp Variation = 1.10°C
# Evaluating fault at 2024-05-11
#   + Included previous day (2024-05-10): 11.46°C
#   + Included next day     (2024-05-12): 12.42°C
#   -> Fault Detected: Temp Variation = 1.10°C
# Evaluating fault at 2024-05-12
#   + Included previous day (2024-05-11): 12.56°C
#   + Included next day     (2024-05-13): 14.65°C
#   -> Fault Detected: Temp Variation = 2.23°C
# Evaluating fault at 2024-05-13
#   + Included previous day (2024-05-12): 12.42°C
#   + Included next day     (2024-05-14): 16.61°C
#   -> Fault Detected: Temp Variation = 4.19°C
# Evaluating fault at 2024-05-15
#   + Included previous day (2024-05-14): 16.61°C
#   + Included next day     (2024-05-16): 17.14°C
#   -> Fault Detected: Temp Variation = 1.15°C
# Evaluating fault at 2024-05-20
#   + Included previous day (2024-05-19): 17.93°C
#   + Included next day     (2024-05-21): 18.20°C
#   -> Fault Detected: Temp Variation = 0.44°C
# Evaluating fault at 2024-06-07
#   + Included previous day (2024-06-06): 11.76°C
#   + Included next day     (2024-06-08): 12.29°C
#   -> Fault Detected: Temp Variation = 0.53°C
# Evaluating fault at 2024-06-09
#   + Included previous day (2024-06-08): 12.29°C
#   + Included next day     (2024-06-10): 13.39°C
#   -> Fault Detected: Temp Variation = 1.58°C
# Evaluating fault at 2024-06-15
#   + Included previous day (2024-06-14): 13.91°C
#   + Included next day     (2024-06-16): 16.04°C
#   -> Fault Detected: Temp Variation = 2.13°C
# Evaluating fault at 2024-06-16
#   + Included previous day (2024-06-15): 14.32°C
#   + Included next day     (2024-06-17): 15.85°C
#   -> Fault Detected: Temp Variation = 1.71°C
# Evaluating fault at 2024-06-17
#   + Included previous day (2024-06-16): 16.04°C
#   + Included next day     (2024-06-18): 14.73°C
#   -> Fault Detected: Temp Variation = 1.30°C
# Evaluating fault at 2024-06-18
#   + Included previous day (2024-06-17): 15.85°C
#   + Included next day     (2024-06-19): 14.54°C
#   -> Fault Detected: Temp Variation = 1.31°C
# Evaluating fault at 2024-06-19
#   + Included previous day (2024-06-18): 14.73°C
#   + Included next day     (2024-06-20): 15.13°C
#   -> Fault Detected: Temp Variation = 0.59°C
# Evaluating fault at 2024-06-20
#   + Included previous day (2024-06-19): 14.54°C
#   + Included next day     (2024-06-21): 16.32°C
#   -> Fault Detected: Temp Variation = 1.78°C
# Evaluating fault at 2024-06-21
#   + Included previous day (2024-06-20): 15.13°C
#   + Included next day     (2024-06-22): 14.16°C
#   -> Fault Detected: Temp Variation = 2.17°C
# Evaluating fault at 2024-06-22
#   + Included previous day (2024-06-21): 16.32°C
#   + Included next day     (2024-06-23): 15.36°C
#   -> Fault Detected: Temp Variation = 2.17°C
# Evaluating fault at 2024-06-24
#   + Included previous day (2024-06-23): 15.36°C
#   + Included next day     (2024-06-25): 17.17°C
#   -> Fault Detected: Temp Variation = 1.81°C
# Evaluating fault at 2024-06-25
#   + Included previous day (2024-06-24): 15.52°C
#   + Included next day     (2024-06-26): 20.12°C
#   -> Fault Detected: Temp Variation = 4.61°C
# Evaluating fault at 2024-08-03
#   + Included previous day (2024-08-02): 15.84°C
#   + Included next day     (2024-08-04): 17.16°C
#   -> Fault Detected: Temp Variation = 1.32°C
# Evaluating fault at 2024-08-07
#   + Included previous day (2024-08-06): 18.91°C
#   + Included next day     (2024-08-08): 19.11°C
#   -> Fault Detected: Temp Variation = 2.44°C
# Evaluating fault at 2024-10-04
#   + Included previous day (2024-10-03): 9.94°C
#   + Included next day     (2024-10-05): 8.94°C
#   -> Fault Detected: Temp Variation = 1.67°C
# Evaluating fault at 2024-10-05
#   + Included previous day (2024-10-04): 8.27°C
#   + Included next day     (2024-10-06): 9.91°C
#   -> Fault Detected: Temp Variation = 1.64°C
# Evaluating fault at 2024-10-07
#   + Included previous day (2024-10-06): 9.91°C
#   + Included next day     (2024-10-08): 13.18°C
#   -> Fault Detected: Temp Variation = 3.28°C
# Evaluating fault at 2024-10-15
#   + Included previous day (2024-10-14): 8.54°C
#   + Included next day     (2024-10-16): 7.95°C
#   -> Fault Detected: Temp Variation = 3.71°C
# Evaluating fault at 2024-10-17
#   + Included previous day (2024-10-16): 7.95°C
#   + Included next day     (2024-10-18): 12.72°C
#   -> Fault Detected: Temp Variation = 4.78°C
# Evaluating fault at 2024-10-21
#   + Included previous day (2024-10-20): 14.28°C
#   + Included next day     (2024-10-22): 12.55°C
#   -> Fault Detected: Temp Variation = 1.73°C
# Evaluating fault at 2024-10-23
#   + Included previous day (2024-10-22): 12.55°C
#   + Included next day     (2024-10-24): 10.38°C
#   -> Fault Detected: Temp Variation = 2.18°C
# Evaluating fault at 2024-10-24
#   + Included previous day (2024-10-23): 12.10°C
#   + Included next day     (2024-10-25): 10.02°C
#   -> Fault Detected: Temp Variation = 2.08°C
# Evaluating fault at 2024-10-25
#   + Included previous day (2024-10-24): 10.38°C
#   + Included next day     (2024-10-26): 11.40°C
#   -> Fault Detected: Temp Variation = 1.39°C
# Evaluating fault at 2024-10-26
#   + Included previous day (2024-10-25): 10.02°C
#   + Included next day     (2024-10-27): 11.32°C
#   -> Fault Detected: Temp Variation = 1.39°C
# Evaluating fault at 2024-10-27
#   + Included previous day (2024-10-26): 11.40°C
#   + Included next day     (2024-10-28): 11.31°C
#   -> Fault Detected: Temp Variation = 0.09°C
# Evaluating fault at 2024-10-28
#   + Included previous day (2024-10-27): 11.32°C
#   + Included next day     (2024-10-29): 11.71°C
#   -> Fault Detected: Temp Variation = 0.40°C
# Evaluating fault at 2024-10-29
#   + Included previous day (2024-10-28): 11.31°C
#   + Included next day     (2024-10-30): 11.77°C
#   -> Fault Detected: Temp Variation = 0.45°C
# TP=17, FP=74, precision=0.187
# True Positives  (TP): 17
# False Positives (FP): 74
# Precision         : 0.187
# TP=17, FP=74, FN=13
# Precision = 0.187
# Recall = 0.567
#
# ====================================
# Overall Recall across all buildings   : 0.511
# Overall Precision across all buildings: 0.169
# ====================================
